# %% [markdown]
# Conditional Statement
#
# if
#
# if
#
# if elif else

# %%
marks = int(input("Enter marks"))
passing = 60
if marks >= passing:
    print("Congratulations you pass")
# Out:
# Congratulations you pass

# %%
marks = int(input("Enter marks"))
passing = 60
if marks >= passing:
    print("Congratulations you pass")
else:
    print("You fail")
# Out:
# Congratulations you pass

# %%
marks = int(input("Enter marks"))
passing = 60
if marks > passing:
    print("Congratulations you pass")
elif marks ==passing:
    print("you pass try next better")
else:
    print("You fail")
# Out:
# you pass try next better
